# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../Health_cleaned.csv')
df.head()
# Out:
#       hhidpn rmstat  ragender rahispan raracem     riwbegy  ragey_b sagey_b  \
# 0   22861040      1         2        0       2  1992-04-01       62      56
# 1  501709010      1         1        0       1  2004-06-15       54      52
# 2  501409020      1         1        0       1  2004-06-15       51      47
# 3  502578010      1         2        1       3  2004-06-15       53      54
# 4  501404010      1         1        0       1  2004-06-15       55      53
#
#   rhltc rhlthlm  ... sgov_delta total_work_income_delta  \
# 0     5       1  ...        NaN                     NaN
# 1    .m       1  ...        NaN                     NaN
# 2    .m       0  ...        NaN                     NaN
# 3    .m       0  ...        NaN                     NaN
# 4    .m       0  ...        NaN                     NaN
#
#   total_pension_income_delta total_gov_income_delta total_income_delta broken  \
# 0                        NaN                    NaN                NaN      0
# 1                        NaN                    NaN                NaN      0
# 2                        NaN                    NaN                NaN      0
# 3                        NaN                    NaN                NaN      0
# 4                        NaN                    NaN                NaN      0
#
#   mariage_group age_group marriage_group child
# 0       married    middle       together    .m
# 1           NaN    middle       together    .m
# 2           NaN    middle       together    .m
# 3           NaN    middle       together    .m
# 4           NaN    middle       together    .m
#
# [5 rows x 65 columns]

# %%
df['riwbegy'] = pd.to_datetime(df['riwbegy'])

# %%
def count_jobs(row):
    job1 = not (row['rjweeks'] == '.m' or row['rjweeks'] == '0')
    job2 = not (row['rjweek2'] == '.m' or row['rjweek2'] == '0')

    if job1 and job2:
        return 2
    elif job1 or job2:
        return 1
    return 0


df['n_jobs'] = df.apply(count_jobs, axis=1)

# %%
df.sort_values('index_wave', inplace=True)

# %%
cpi_by_year = df.groupby('index_wave')['cpi'].median()
cpi_by_year
# Out:
# index_wave
# 1     0.934777
# 2     0.967805
# 3     1.028097
# 4     1.068196
# 5     1.133913
# 6     1.028097
# 7     1.068196
# 8     1.133913
# 9     1.204051
# 10    1.245748
# 11    1.306293
# Name: cpi, dtype: float64

# %%
income_columns = ['riearn', 'siearn', 'ripena', 'sipena', 'rgov', 'sgov', 'total_work_income',
        'total_pension_income', 'total_gov_income', 'total_income']

# %%
for el in df.iterrows():
    for col in income_columns:
        df.loc[el[0], col] *= el[1]['index_wave']

# %%
unique_ids = df['hhidpn'].unique()
unique_ids.shape
# Out:
# (31532,)

# %%
df.columns
# Out:
# Index(['hhidpn', 'rmstat', 'ragender', 'rahispan', 'raracem', 'riwbegy',
#        'ragey_b', 'sagey_b', 'rhltc', 'rhlthlm', 'rhibpe', 'rdiabe', 'rcancre',
#        'rlunge', 'rhearte', 'rstroke', 'rpsyche', 'rarthre', 'rhosp',
#        'rhspnit', 'oop_spend', 'riearn', 'ripena', 'siearn', 'sipena', 'rcovr',
#        'rcovs', 'rlbrf', 'rjphys', 'rjlift', 'rjweeks', 'rjweek2', 'rjcten',
#        'index_wave', 'insured_gov', 'uninsured', 'retired', 'collegeplus',
#        'year', 'cpi', 'rgov', 'sgov', 'inter_year', 'year_of_birth',
#        'total_work_income', 'total_pension_income', 'total_gov_income',
#        'total_income', 'without_work', 'n_jobs', 'riearn_delta',
#        'siearn_delta', 'ripena_delta', 'sipena_delta', 'rgov_delta',
#        'sgov_delta', 'total_work_income_delta', 'total_pension_income_delta',
#        'total_gov_income_delta', 'total_income_delta', 'broken',
#        'mariage_group', 'age_group', 'marriage_group', 'child'],
#       dtype='object')

# %%
df.head()
# Out:
#          hhidpn rmstat  ragender rahispan raracem    riwbegy  ragey_b sagey_b  \
# 0      22861040      1         2        0       2 1992-04-01       62      56
# 18878  83974040      1         2        0       1 1992-09-22       50      51
# 18877  36832030      1         1        0       1 1992-09-22       63      57
# 18876  15014010      1         2        0       1 1992-09-22       55      62
# 18875  83613010      7         2        0       1 1992-09-22       57      .m
#
#       rhltc rhlthlm  ... sgov_delta total_work_income_delta  \
# 0         5       1  ...        NaN                     NaN
# 18878     3       0  ...        NaN                     NaN
# 18877     3       0  ...        NaN                     NaN
# 18876     2       0  ...        NaN                     NaN
# 18875     2       0  ...        NaN                     NaN
#
#       total_pension_income_delta total_gov_income_delta total_income_delta  \
# 0                            NaN                    NaN                NaN
# 18878                        NaN                    NaN                NaN
# 18877                        NaN                    NaN                NaN
# 18876                        NaN                    NaN                NaN
# 18875                        NaN                    NaN                NaN
#
#       broken mariage_group age_group marriage_group child
# 0          0       married    middle       together    .m
# 18878      0       married    middle       together    .m
# 18877      0       married    middle       together    .m
# 18876      0       married    middle       together    .m
# 18875      0   dead spouse    middle    dead spouse    .m
#
# [5 rows x 65 columns]

# %%
df['rmstat'].value_counts()
# Out:
# 1     96997
# 7     27626
# 5     14136
# 1     11073
# 8      5476
# 3      5272
# 4      2551
# 7      2390
# 5      1529
# 2      1146
# 6      1059
# 8       479
# 3       476
# 4       314
# 2       118
# .m      114
# 6         5
# Name: rmstat, dtype: int64

# %%
def count_deltas(rows):
    income_deltas = {}

    for col in income_columns:
        income_deltas[f'{col}_delta'] = [np.nan]

    indexes = rows.index

    for i, (_, row) in zip(range(len(indexes)), rows.iterrows()):
        if i == 0:
            continue
        prev_row = rows.loc[indexes[i - 1]]

        valid_interval = True
        current_year = row['year']
        if current_year - prev_row['year'] > 2:
            valid_interval = False

        for col in income_columns:
            if not valid_interval or prev_row[col] == 0 or row[col] == 0:
                income_deltas[f'{col}_delta'].append(np.nan)
            else:
                income_deltas[f'{col}_delta'].append(row[col] / prev_row[col] * 100  - 100)

    return income_deltas

# %%
def check_if_broken(rows):
    indexes = rows.index
    broken = False
    was_married = False

    statuses = rows['rmstat']

    for st in statuses:
        if st == '.m' or int(st) not in [1, 2, 5, 7]:
            broken = False
            break
            
        if int(st) == 1:
            was_married = True

        if int(st) in [2, 5, 7]:
            if was_married:
                broken = True
            else:
                broken = False
                break
    
        if broken and int(st) not in [2, 5, 7]:
            broken = False
            break

    return int(broken)

# %%
broken = []

for uid in unique_ids:
    result = check_if_broken(df[df['hhidpn'] == uid])

    df.loc[df['hhidpn'] == uid, 'broken'] = result

df.head()
# Out:
#          hhidpn rmstat  ragender rahispan raracem    riwbegy  ragey_b sagey_b  \
# 0      22861040      1         2        0       2 1992-04-01       62      56
# 18878  15014010      1         2        0       1 1992-09-22       55      62
# 18877  83613010      7         2        0       1 1992-09-22       57      .m
# 18876  83977010      1         2        0       1 1992-09-22       55      57
# 18875  77679030      1         2        0       2 1992-09-22       46      53
#
#       rhltc rhlthlm  ... rgov_delta sgov_delta total_work_income_delta  \
# 0        -2       1  ...        NaN        NaN                     NaN
# 18878     1       0  ...        NaN        NaN                     NaN
# 18877     1       0  ...        NaN        NaN                     NaN
# 18876     0       0  ...        NaN        NaN                     NaN
# 18875     0      .m  ...        NaN        NaN                     NaN
#
#       total_pension_income_delta total_gov_income_delta total_income_delta  \
# 0                            NaN                    NaN                NaN
# 18878                        NaN                    NaN                NaN
# 18877                        NaN                    NaN                NaN
# 18876                        NaN                    NaN                NaN
# 18875                        NaN                    NaN                NaN
#
#       broken mariage_group age_group marriage_group
# 0          0       married    middle       together
# 18878      0       married    middle       together
# 18877      0   dead spouse    middle    dead spouse
# 18876      0       married    middle       together
# 18875      1       married    middle       together
#
# [5 rows x 64 columns]

# %%
df[df['broken'] == True].groupby('hhidpn')['rmstat'].unique()
# Out:
# hhidpn
# 10004040     [1, 1, 7]
# 10075020     [1, 1, 7]
# 10109030        [1, 7]
# 10210020     [1, 1, 7]
# 10395020     [1, 1, 7]
#                ...
# 918529020       [1, 2]
# 919258010       [1, 5]
# 919258020       [1, 5]
# 920538010       [1, 2]
# 920538020       [1, 2]
# Name: rmstat, Length: 3480, dtype: object

# %%
for uid in unique_ids:
    break
    income_deltas = count_deltas(df[df['hhidpn'] == uid])

    for col in income_columns:
        df.loc[df['hhidpn'] == uid, f'{col}_delta'] = income_deltas[f'{col}_delta']

# %%
df[df['hhidpn'] == 22861010][income_columns + [f'{col}_delta' for col in income_columns]]
# Out:
#               riearn  siearn  ripena  sipena       rgov        sgov  \
# 4       23485.564002     0.0     0.0     0.0     0.0000   3522.8347
# 11019   25280.287153     0.0     0.0     0.0     0.0000   3768.0933
# 25453   23157.354808     0.0     0.0     0.0     0.0000   5252.3936
# 38758   25473.632823     0.0     0.0     0.0     0.0000  10436.9110
# 54929    9841.727323     0.0     0.0     0.0  8843.4951  12653.6490
# 74948   19852.633829     0.0     0.0     0.0  8338.1064   7279.2988
# 97052       0.000000     0.0     0.0     0.0  8177.9585   7197.1133
# 103235      0.000000     0.0     0.0     0.0  8028.0000  29991.3520
# 121846      0.000000     0.0     0.0     0.0  7955.8916  10566.4180
# 140706      0.000000     0.0     0.0     0.0     0.0000   8585.2588
# 154535      0.000000     0.0     0.0     0.0  8301.9248   9708.1475
#
#         total_work_income  total_pension_income  total_gov_income  \
# 4            23485.564002                   0.0         3522.8347
# 11019        25280.287153                   0.0         3768.0933
# 25453        23157.354808                   0.0         5252.3936
# 38758        25473.632823                   0.0        10436.9110
# 54929         9841.727323                   0.0        21497.1441
# 74948        19852.633829                   0.0        15617.4052
# 97052            0.000000                   0.0        15375.0718
# 103235           0.000000                   0.0        38019.3520
# 121846           0.000000                   0.0        18522.3096
# 140706           0.000000                   0.0         8585.2588
# 154535           0.000000                   0.0        18010.0723
#
#         total_income  riearn_delta  siearn_delta  ripena_delta  sipena_delta  \
# 4       27008.398702           NaN           NaN           NaN           NaN
# 11019   29048.380453     -8.265564           NaN           NaN           NaN
# 25453   28409.748408    -18.366358           NaN           NaN           NaN
# 38758   35910.543823      2.827702           NaN           NaN           NaN
# 54929   31338.871423    -62.608905           NaN           NaN           NaN
# 74948   35470.039029    107.386738           NaN           NaN           NaN
# 97052   15375.071800           NaN           NaN           NaN           NaN
# 103235  38019.352000           NaN           NaN           NaN           NaN
# 121846  18522.309600           NaN           NaN           NaN           NaN
# 140706   8585.258800           NaN           NaN           NaN           NaN
# 154535  18010.072300           NaN           NaN           NaN           NaN
#
#         rgov_delta  sgov_delta  total_work_income_delta  \
# 4              NaN         NaN                      NaN
# 11019          NaN   -8.844943                -8.265564
# 25453          NaN   24.221806               -18.366358
# 38758          NaN   85.747472                 2.827702
# 54929          NaN   17.336072               -62.608905
# 74948    -3.065657  -40.856375               107.386738
# 97052     4.767992    5.613624                      NaN
# 103235   11.312073  372.517084                      NaN
# 121846   19.323598  -57.579421                      NaN
# 140706         NaN    1.217546                      NaN
# 154535         NaN   47.714640                      NaN
#
#         total_pension_income_delta  total_gov_income_delta  total_income_delta
# 4                              NaN                     NaN                 NaN
# 11019                          NaN               -8.844943           -8.341135
# 25453                          NaN               24.221806          -12.841913
# 38758                          NaN               85.747472           18.157907
# 54929                          NaN               99.340952          -15.540382
# 74948                          NaN              -25.310030           16.362352
# 97052                          NaN                5.162142          -53.697266
# 103235                         NaN              180.393130          180.393130
# 121846                         NaN              -41.340916          -41.340916
# 140706                         NaN              -42.258448          -42.258448
# 154535                         NaN              174.032852          174.032852

# %%
def reformat_rhltc(el):
    if el == '.m':
        return el
    return 3 - int(el)


def return_group(el):
    if el == '.m':
        return '.m'
    if int(el) == 1 or int(el) == 3:
        return 'together'
    if int(el) == 2:
        return 'absent spouse'
    if int(el) == 4:
        return 'separated'
    if int(el) == 5:
        return 'divorced'
    if int(el) == 6:
        return '.m'
    if int(el) == 7:
        return 'dead spouse'
    if int(el) == 8:
        return 'never married'


def return_age_group(el):
    age = int(el)
    if age < 45:
        return 'young'
    elif 45 <= age <= 65:
        return 'middle'
    elif 65 <= age <= 80:
        return 'old'
    else:
        return 'dead outside'

df['rhltc'] = df['rhltc'].apply(reformat_rhltc)
df['marriage_group'] = df['rmstat'].apply(return_group)
df['age_group'] = df['ragey_b'].apply(return_age_group)

# %%
df.head()
# Out:
#           hhidpn rmstat  ragender rahispan raracem    riwbegy  ragey_b  \
# 0       22861040      1         2        0       2 1992-04-01       62
# 90806  502578010      1         2        1       3 2004-06-15       53
# 90812  501404010      1         1        0       1 2004-06-15       55
# 90831  501699020      1         1        0       1 2004-06-15       52
# 90832  501445010      8         2        0       2 2004-06-15       56
#
#       sagey_b rhltc rhlthlm  ... rgov_delta sgov_delta  \
# 0          56    -2       1  ...        NaN        NaN
# 90806      54    .m       0  ...        NaN        NaN
# 90812      53    .m       0  ...        NaN        NaN
# 90831      48    .m       0  ...        NaN        NaN
# 90832      .m    .m       1  ...        NaN        NaN
#
#       total_work_income_delta total_pension_income_delta  \
# 0                         NaN                        NaN
# 90806                     NaN                        NaN
# 90812                     NaN                        NaN
# 90831                     NaN                        NaN
# 90832                     NaN                        NaN
#
#       total_gov_income_delta total_income_delta broken mariage_group  \
# 0                        NaN                NaN      0       married
# 90806                    NaN                NaN      0           NaN
# 90812                    NaN                NaN      0           NaN
# 90831                    NaN                NaN      0           NaN
# 90832                    NaN                NaN      0           NaN
#
#       age_group marriage_group
# 0        middle       together
# 90806    middle       together
# 90812    middle       together
# 90831    middle       together
# 90832    middle  never married
#
# [5 rows x 64 columns]

# %%
df['age_group'].value_counts().reindex(['young', 'middle', 'old', 'dead outside'])
# Out:
# young            32770
# middle          110607
# old              25655
# dead outside      1729
# Name: age_group, dtype: int64

# %%
# child_csv = pd.read_csv('../child.csv', low_memory=False)
# child_csv.shape
# Out:
# (103430, 3)

# %%
# child_csv['hhidpn'] = child_csv['hhidpn'].astype(int)

# %%
# child_csv = child_csv[child_csv['child'] != '.m']
# child_csv['child'] = child_csv['child'].astype(int)
# child_csv.sort_values(by='index_wave', inplace=True)
# child_csv.shape
# Out:
# (7054, 3)

# %%
# df['child'] = [np.nan] * df.shape[0]

# %%
# for id in unique_ids:
#     cid = id // 1000
#     tmp = child_csv[child_csv['hhidpn'] == cid]

#     for i, el in tmp.iterrows():
#         df.loc[(df['hhidpn'] == id) & (df['index_wave'] == el['index_wave']), 'child'] = el['child']

# %%
# df['child'].replace({np.nan: '.m'}, inplace=True)
# df['child'].value_counts()
# Out:
# .m     165177
# 0.0      3157
# 1.0      2427
# Name: child, dtype: int64

# %%
df.to_csv('../Health_cleaned_income_delta.csv', index=False)
