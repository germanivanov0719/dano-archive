# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ExploriPy import EDA
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv('~/downloads/df_for_polymer.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0   id                economic_sector company_size  \
# 0             0           2   34            Другое Производство      Средний
# 1             1           3   50  Готовые Металлические Изделия        Малый
# 2             2           5   90                  Другие Услуги      Средний
# 3             3           7  126             Розничная торговля        Малый
# 4             4          11  142             Розничная торговля      Средний
#
#                 federal_district       service_types  \
# 0  Центральный Федеральный округ        Производство
# 1  Центральный Федеральный округ       Другие услуги
# 2  Центральный Федеральный округ       Другие услуги
# 3  Центральный Федеральный округ  Розничная торговля
# 4  Центральный Федеральный округ  Розничная торговля
#
#                                    organization_form initial_year  \
# 0  Акционерная компания с неторгуемыми акциями ил...         2005
# ...

# %%
# CategoricalFeatures = ["a4a", "a6a", "a2", "b1"]
eda = EDA(
    df[filter(lambda x: x not in ['Unnamed: _0', 'id'], df.columns)],
    # CategoricalFeatures,
    # OtherFeatures=["b5"],
    title="eda",
)
eda.TargetAnalysis("ecology_index")  # For Target Specific Analysis

eda.EDAToHTML("./eda.html")
# Out:
# Converting Categorical Features to String...
# 100%|██████████| 30/30 [00:00<00:00, 3386.33it/s]
# Initiating Target Specific Analysis...
# Generating Correlation Heatmap...
# Calculating Target Percentage...
# Performing ChiSquare Test of Independence...
# 100%|██████████| 30/30 [00:00<00:00, 143.80it/s]
# Calculate the Target Distributions...
# 100%|██████████| 30/30 [00:01<00:00, 17.87it/s]
# Generating Distribution Charts...
#  20%|██        | 1/5 [00:06<00:26,  6.70s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 8
#       1 # CategoricalFeatures = ["a4a", "a6a", "a2", "b1"]
#       2 eda = EDA(
#       3     df[filter(lambda x: x not in ['Unnamed: _0', 'id'], df.columns)],
#       4     # CategoricalFeatures,
#       5     # OtherFeatures=["b5"],
#       6     title="eda",
#       7 )
# ...
